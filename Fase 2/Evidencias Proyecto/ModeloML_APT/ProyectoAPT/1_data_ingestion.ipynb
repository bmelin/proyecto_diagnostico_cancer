# %%
# ============================================
# 1 INGESTA DE DATOS
# ============================================
import pandas as pd

# Cargar archivo
archivo = "pacientes_10000_final.csv"
df = pd.read_csv(archivo)

print(f"Datos cargados correctamente desde: {archivo}")
print(f"Total de registros: {len(df)}")
print("\nColumnas disponibles:")
print(df.columns.tolist())
# Out:
# Datos cargados correctamente desde: pacientes_10000_final.csv
# Total de registros: 10000
#
# Columnas disponibles:
# ['id_paciente', 'nombre', 'rut', 'edad', 'sexo', 'fecha_registro', 'id_medico', 'FamiliarPrimerGradoCC', 'FamiliarSegundoGradoCC', 'DiagnosticoPrevioCancer', 'Ejercicio', 'Alcohol', 'Mamografia', 'Menstruacion', 'PrimerHijo', 'Riesgo']

# %%
# Vista previa de los datos
pd.set_option('display.max_columns', None)
display(df.head(10))
# Out:
#    id_paciente        nombre        rut   edad sexo fecha_registro  id_medico  \
# 0            1      Michelle  817097948   91.0    F      9/10/2025          1
# 1            2      Carmelle  464769004    8.0    F      9/10/2025          1
# 2            3      Consuelo  637151220   43.0    F      9/10/2025          1
# 3            4       Marjory  790245753   99.0    F      9/10/2025          1
# 4            5      Joycelin  620959095   43.0    F      9/10/2025          1
# 5            6         Antin  411672499  134.0    M      9/10/2025          1
# 6            7        Sidnee  845580106   64.0    M      9/10/2025          1
# 7            8  Christabella  155534787   97.0    F      9/10/2025          1
# 8            9      Krystyna  973607815  145.0    F      9/10/2025          1
# 9           10          Jeth  133362594   53.0    M      9/10/2025          1
#
#   FamiliarPrimerGradoCC  FamiliarSegundoGradoCC  DiagnosticoPrevioCancer  \
# 0                 False                    True                     True
# 1                 False                   False                    False
# 2                  True                   False                    False
# 3                  True                    True                     True
# 4                 False                   False                     True
# 5                 False                   False                     True
# 6                  True                    True                    False
# 7                  True                   False                    False
# 8                  True                    True                    False
# 9                  True                   False                    False
#
#    Ejercicio    Alcohol  Mamografia     Menstruacion        PrimerHijo  \
# 0   <3 horas      Nunca        True  Primer hijo <30  Primer hijo >=30
# 1    Ninguna  Ocasional       False  Primer hijo <30   Primer hijo <30
# 2    Ninguna  Ocasional       False  Primer hijo <30   Primer hijo <30
# 3   <3 horas  Ocasional        True  Primer hijo <30          No hijos
# 4   >4 horas     Diario       False         No hijos   Primer hijo <30
# 5  3-4 horas  Ocasional       False         No hijos   Primer hijo <30
# 6   >4 horas      Nunca       False         No hijos  Primer hijo >=30
# 7   <3 horas  Frecuente       False  Primer hijo <30   Primer hijo <30
# 8   >4 horas  Ocasional       False  Primer hijo <30   Primer hijo <30
# 9   >4 horas  Frecuente        True              NaN          No hijos
#
#      Riesgo
# 0      Bajo
# 1      Bajo
# 2      Bajo
# 3      Bajo
# 4      Bajo
# 5      Bajo
# 6      Alto
# 7      Bajo
# 8      Bajo
# 9  Moderado

# %%
# Información general
print("\nInformación general:")
df.info()

# Valores nulos
print("\nValores nulos por columna:")
print(df.isnull().sum())

# Valores únicos por columna
print("\nValores únicos por columna:")
for c in df.columns:
    print(f"{c}: {df[c].nunique()} únicos")
# Out:
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_paciente              10000 non-null  int64
#  1   nombre                   10000 non-null  object
#  2   rut                      10000 non-null  int64
#  3   edad                     9590 non-null   float64
#  4   sexo                     10000 non-null  object
#  5   fecha_registro           10000 non-null  object
#  6   id_medico                10000 non-null  int64
#  7   FamiliarPrimerGradoCC    9675 non-null   object
#  8   FamiliarSegundoGradoCC   10000 non-null  bool
#  9   DiagnosticoPrevioCancer  10000 non-null  bool
#  10  Ejercicio                9191 non-null   object
#  11  Alcohol                  10000 non-null  object
#  12  Mamografia               10000 non-null  bool
#  13  Menstruacion             9386 non-null   object
#  14  PrimerHijo               10000 non-null  object
#  15  Riesgo                   10000 non-null  object
# dtypes: bool(3), float64(1), int64(3), object(9)
# memory usage: 1.0+ MB
#
# Valores nulos por columna:
# id_paciente                  0
# nombre                       0
# rut                          0
# edad                       410
# sexo                         0
# fecha_registro               0
# id_medico                    0
# FamiliarPrimerGradoCC      325
# FamiliarSegundoGradoCC       0
# DiagnosticoPrevioCancer      0
# Ejercicio                  809
# Alcohol                      0
# Mamografia                   0
# Menstruacion               614
# PrimerHijo                   0
# Riesgo                       0
# dtype: int64
#
# Valores únicos por columna:
# id_paciente: 6694 únicos
# nombre: 5820 únicos
# rut: 10000 únicos
# edad: 150 únicos
# sexo: 2 únicos
# fecha_registro: 1 únicos
# id_medico: 1 únicos
# FamiliarPrimerGradoCC: 2 únicos
# FamiliarSegundoGradoCC: 2 únicos
# DiagnosticoPrevioCancer: 2 únicos
# Ejercicio: 4 únicos
# Alcohol: 4 únicos
# Mamografia: 2 únicos
# Menstruacion: 3 únicos
# PrimerHijo: 3 únicos
# Riesgo: 3 únicos

# %%
# Guardar copia inicial limpia
df.to_csv("data_raw.csv", index=False)
print("Archivo guardado como 'data_raw.csv'")
# Out:
# Archivo guardado como 'data_raw.csv'
